# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.imagito.analysis import *
from fastai.imagito.plots import *

import pandas as pd
cti = pd.read_msgpack('cti.mp')
make_scatter(cti, ['Hard Examples', 'Easy Examples', 'Random', 'Hard Examples (*)',], hue='M2')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/shleifer/miniconda3/envs/cs231n/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/shleifer/miniconda3/envs/cs231n/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/shleifer/miniconda3/envs/cs231n/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# ...

# %% [markdown]
# ### Drilldown

# %%
df = pd.read_msgpack('all_results.mp')

# %%
mg = make_pl_data(df)

# %%
mg.shape
# Out:
# (2255, 44)

# %%
mg.pipe(drop_zero_variance_cols).shape
# Out:
# (2255, 33)

# %%
mg[STRAT].unique()
# Out:
# array(['All Classes-1.0-ep5', 'All Classes-1.0', 'All Classes-0.5', 'All Classes-0.25', 'Other Half Classes-1.0',
#        'Half Classes-1.0', 'Half Classes-0.5', 'Half Classes-0.25', 'All Classes-0.7', 'Half Classes-0.7',
#        'All Classes-0.1', 'Half Classes-0.1', '2Classes-1.0', '2Classes-0.5', '2Classes-0.1', 'All Classes-1.0-ep10',
#        'hard-0.0-0.1', 'hard-0.0-0.75', 'distillation', 'hard-0.9-1.0', 'hard-0.75-1.0', 'hard-0.5-1.0',
#        'hard-0.25-1.0', 'hard-0.0-0.5', 'hard-0.0-0.25', 'All Classes-1.0-ep1', 'hard-0.05-0.5'], dtype=object)

# %%
#mg['nsteps']

# %%
drilldown_plot(mg,  'All Classes-0.7', xcol=ACCURACY)
